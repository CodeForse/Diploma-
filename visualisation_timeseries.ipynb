# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel('./data/dataset_almaty_2023.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_excel('./data/dataset_almaty_2023.xlsx')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'prime_key', 'krisha_id', 'title', 'price', 'location',
#        'description', 'is_mortgaged', 'seller', 'city', 'date_creation',
#        'num_views', 'is_hot', 'is_paid_up', 'is_hyped_turbo', 'is_cold_entry',
#        'num_pictures', 'num_rooms', 'area', 'floor', 'total_floors',
#        'year_builded', 'ceiling_height'],
#       dtype='object')

# %%
df['price_per_m2'] = df['price']/df['area']

# %%
df.plot.scatter(x='area', y='price_per_m2', c='DarkBlue')
# Out:
# <AxesSubplot: xlabel='area', ylabel='price_per_m2'>

# %%
df = pd.read_excel('./data/data2023.xlsx')

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'cv ', 'prime_key', 'krisha_id', 'price',
#        'description', 'is_mortgaged', 'seller', 'city', 'date_creation',
#        'num_views', 'is_hot', 'is_paid_up', 'is_hyped_turbo', 'is_cold_entry',
#        'num_pictures', 'num_rooms', 'Area', 'floor', 'total_floors',
#        'year_builded', 'ceiling_height', 'Region', 'Address', 'Price per Area',
#        'f/tf', 'Full Address', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x='krisha_id',y='price')
plt.xlim(left=6.55e8, right=6.85e8)
# Out:
# (655000000.0, 685000000.0)

# %%
df_may = pd.read_excel('./data/data2023m.xlsx')

# %%
sns.scatterplot(data=df_may, x='krisha_id',y='price')
plt.xlim(left=6.55e8, right=6.86e8)
# Out:
# (655000000.0, 686000000.0)

# %%
df.krisha_id.mean()
# Out:
# 678056792.525896

# %%
df_may.krisha_id.mean()
# Out:
# 679204894.8302605

# %%
df22 = pd.read_excel('./data/data2022.xlsx')

# %%
sns.scatterplot(data=df22, x='krisha_id',y='price')
# plt.xlim(left=6.55e8, right=6.86e8)
# Out:
# <AxesSubplot: xlabel='krisha_id', ylabel='price'>

# %%
df21 = pd.read_excel('./data/data2021_first.xlsx')

# %%
sns.scatterplot(data=df21, x='page_url',y='price')
plt.xlim(left=6.55e8, right=6.75e8)
# Out:
# (655000000.0, 675000000.0)

# %%
df19 = pd.read_excel('./data/data2019.xlsx')

# %%
sns.scatterplot(data=df19, x='krisha_id',y='price')
# plt.xlim(left=6.55e8, right=6.75e8)
# Out:
# <AxesSubplot: xlabel='krisha_id', ylabel='price'>

# %%
sns.scatterplot(data=df, x='krisha_id',y='price')
sns.scatterplot(data=df22, x='krisha_id',y='price')
sns.scatterplot(data=df21, x='page_url',y='price')
sns.scatterplot(data=df19, x='krisha_id',y='price')
plt.xlim(left=6.5e8, right=6.85e8)
# Out:
# (450000000.0, 685000000.0)

# %%
sns.scatterplot(data=df21, x='page_url',y='price')
sns.scatterplot(data=df19, x='krisha_id',y='price')
plt.xlim( right=1e8)
# Out:
# (-33463461.950000003, 100000000.0)

# %%
sns.scatterplot(data=df, x='krisha_id',y='price')
sns.scatterplot(data=df22, x='krisha_id',y='price')
sns.scatterplot(data=df21, x='page_url',y='price')
sns.scatterplot(data=df19, x='krisha_id',y='price')
# Out:
# <AxesSubplot: xlabel='krisha_id', ylabel='price'>

# %%
df[df.krisha_id < 1e8].krisha_id
# Out:
# 32       29250908
# 46       29836635
# 47       29759171
# 74       29663279
# 112      56529856
#            ...
# 17097    58272071
# 17133    56814816
# 17218    55346459
# 17328    57711101
# 17448    58275465
# Name: krisha_id, Length: 87, dtype: int64

# %%
df.krisha_id.min()
# Out:
# 17323819

# %%
df_may.krisha_id.min()
# Out:
# 9016108

# %%
df16 = pd.read_excel('./data/data2016.xlsx')

# %%
sns.scatterplot(data=df19, x='krisha_id',y='price')
sns.scatterplot(data=df16, x='krisha_id',y='price')
# Out:
# <AxesSubplot: xlabel='krisha_id', ylabel='price'>

# %%
sns.scatterplot(data=df, x='krisha_id',y='price')
sns.scatterplot(data=df16, x='krisha_id',y='price')

plt.xlim(right=1e8)
# Out:
# (-30506554.550000004, 100000000.0)

# %%
set(df19.krisha_id).intersection(set(df16.krisha_id))
# Out:
# {27829850}

# %%
sns.scatterplot(x=df['krisha_id'],y=df['price']/df['Area'])
sns.scatterplot(x=df16['krisha_id'],y=df16['price']/df16['area'])

plt.xlim(right=1e8)
# Out:
# (-30506554.550000004, 100000000.0)

# %%
sns.scatterplot(x=df['krisha_id'],y=df['price']/df['Area'])
sns.scatterplot(x=df21['page_url'],y=df21['price']/df21['area'])

plt.xlim(right=1e8)
# Out:
# (-33916371.800000004, 100000000.0)

# %%
sns.scatterplot(x=df['krisha_id'],y=df['price']/df['Area'])
sns.scatterplot(x=df21['page_url'],y=df21['price']/df21['area'])

plt.xlim(left=6.59e8, right=6.85e8)
# Out:
# (659000000.0, 685000000.0)

# %%
sns.scatterplot(x=df['krisha_id'],y=df['price'])
sns.scatterplot(x=df21['page_url'],y=df21['price'])

plt.xlim(left=6.59e8, right=6.85e8)
# Out:
# (659000000.0, 685000000.0)

# %%
intersect_21_23 = pd.Series(list(set(df.krisha_id).intersection(set(df21.page_url))))

# %%
df[df.krisha_id.isin(intersect_21_23)].sort_values('krisha_id')['price']
# Out:
#        Unnamed: 0.1  Unnamed: 0    cv   prime_key  krisha_id      price  \
# 845             845         774    788        638   19330206   80000000
# 231             231         207    212       8325   21483758   45000000
# 12732         12732       11218  11340       1525   27290921   62500000
# 142             142         138    140       5306   29700174  113976000
# 150             150         143    146       5408   29760314   78544000
# ...             ...         ...    ...        ...        ...        ...
# 7201           7201        6233   6299       8385  673501216   21000000
# 15363         15363       13609  13781       9761  673504403   30000000
# 16661         16661       14782  14969      13408  673519385   15000000
# 15339         15339       13585  13756       9685  673519515   55000000
# 16989         16989       15102  15296      14619  673522223   25000000
#
#                                              description  is_mortgaged  \
# ...

# %%
df21[df21.page_url.isin(intersect_21_23)].sort_values('page_url')['price']
# Out:
#        Unnamed: 0.1                                              title  \
# 18624         18624  4-комнатная квартира, 107 м², 2//9 этаж, Байза...
# 14606         14606  2-комнатная квартира, 51 м², 1//16 этаж, Муста...
# 2391           2391  3-комнатная квартира, 90 м², 4//9 этаж, мкр №1...
# 3097           3097  4-комнатная квартира, 159.2 м², 7//7 этаж, мкр...
# 16754         16754  3-комнатная квартира, 104 м², 1//7 этаж, мкр М...
# ...             ...                                                ...
# 8095           8095  1-комнатная квартира, 32 м², 4//4 этаж, мкр №1...
# 6336           6336  2-комнатная квартира, 43.5 м², 4//4 этаж, Жаро...
# 16646         16646  1-комнатная квартира, 20.1 м², 2//3 этаж, мкр ...
# 5502           5502  3-комнатная квартира, 83 м², 15//16 этаж, мкр ...
# 18070         18070  1-комнатная квартира, 41 м², 2//5 этаж, мкр Ак...
#
#            price                owner                  flat.city  \
# ...

# %%
df21.rename(columns={'page_url':'krisha_id'}, inplace=True)

# %%
dif_21_23 =(df[df.krisha_id.isin(intersect_21_23)].sort_values('krisha_id')[['krisha_id','price']].rename(columns={'price':'price23'}).drop_duplicates().merge(\
    df21[df21.krisha_id.isin(intersect_21_23)].sort_values('krisha_id')[['krisha_id','price']].rename(columns={'price':'price21'}).drop_duplicates()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dif_21_23 =(df[df.krisha_id.isin(intersect_21_23)].sort_values('krisha_id')[['krisha_id','price']].rename(columns={'price':'price23'}).drop_duplicates().merge(\
#       2     df21[df21.krisha_id.isin(intersect_21_23)].sort_values('krisha_id')[['krisha_id','price']].rename(columns={'price':'price21'}).drop_duplicates()))
#
# NameError: name 'intersect_21_23' is not defined

# %%
sns.histplot(dif_21_23['price23'] - dif_21_23['price21'])
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.lineplot(x=dif_21_23['krisha_id'],y=dif_21_23['price21'])
sns.lineplot(x=dif_21_23['krisha_id'],y=dif_21_23['price23'])
# Out:
# <AxesSubplot: xlabel='krisha_id', ylabel='price21'>

# %%
sns.scatterplot(x=df['krisha_id'],y=df['price'])
sns.scatterplot(x=df_may['krisha_id'],y=df_may['price'])

plt.xlim(left=6.59e8, right=6.85e8)
# Out:
# (659000000.0, 685000000.0)

# %%
df_may['krisha_id'].max()
# Out:
# 860000544

# %%
step_series = (df.krisha_id.drop_duplicates().sort_values() - df.krisha_id.drop_duplicates().sort_values().shift(1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[171], line 2
#       1 step_series = (df.krisha_id.drop_duplicates().sort_values() - df.krisha_id.drop_duplicates().sort_values().shift(1))
# ----> 2 sns.histplot(step_series)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:1432, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421 estimate_kws = dict(
#    1422     stat=stat,
#    1423     bins=bins,
#    (...)
#    1427     cumulative=cumulative,
#    1428 )
#    1430 if p.univariate:
# ...

# %%
intersect_23_23may = pd.Series(list(set(df.krisha_id).intersection(set(df_may.krisha_id))))

df[~df.krisha_id.isin(intersect_23_23may)].sort_values('krisha_id')[['krisha_id','price']].drop_duplicates()
# Out:
#        krisha_id      price
# 13548   17323819   15000000
# 15608   18540020  200000000
# 845     19330206   80000000
# 12964   21040224   50000000
# 231     21483758   45000000
# ...          ...        ...
# 12867  682581737   27200000
# 2435   682581750   26500000
# 2434   682581779   71000000
# 12865  682581801   35500000
# 2433   682581805   57000000
#
# [13624 rows x 2 columns]

# %%
df['YEAR'] = 2023
df22['YEAR'] = 2022
df21['YEAR'] = 2021
df19['YEAR'] = 2019
df16['YEAR'] = 2016

# %%
df_join = pd.concat([df[['krisha_id','price','YEAR']],df22[['krisha_id','price','YEAR']],df21[['krisha_id','price','YEAR']],df19[['krisha_id','price','YEAR']],df16[['krisha_id','price','YEAR']]])

# %%
df_join = df_join.sort_values('krisha_id', ascending=False).drop_duplicates(keep='last')

# %%
sns.scatterplot(df_join, x='krisha_id', y='price',hue='YEAR', palette='bright')
# Out:
# <AxesSubplot: xlabel='krisha_id', ylabel='price'>

# %%
sns.scatterplot(df_join, x='krisha_id', y='price',hue='YEAR', palette='bright')

plt.xlim(left = 0,right=0.6e8)
# Out:
# (0.0, 60000000.0)

# %%
sns.scatterplot(df_join, x='krisha_id', y='price',hue='YEAR', palette='bright')

plt.xlim(left=6.58e8, right=6.85e8)
# Out:
# (658000000.0, 685000000.0)

# %%
df_join.agg(['min','max'])
# Out:
#        krisha_id       price  YEAR
# min     202589.0       25500  2016
# max  682581805.0  1935000000  2023

# %%
sns.scatterplot(df_join, x='krisha_id', y='price',hue='YEAR', palette='bright')

plt.xlim(left=6.58e8, right=6.85e8)
plt.ylim(top=0.25e9)
# Out:
# (-96723225.0, 250000000.0)

# %%
sns.scatterplot(df_join, x='krisha_id', y='price',hue='YEAR', palette='bright')

plt.xlim(left = 0,right=0.6e8)
plt.ylim(top=0.25e9)
# Out:
# (-96723225.0, 250000000.0)

# %%
df_join.agg(['min','max'])
# Out:
#        krisha_id       price  YEAR
# min     202589.0       25500  2016
# max  682581805.0  1935000000  2023

# %%
df_join.price.sort_values()
# Out:
# 13003         25500
# 15598       2600000
# 57          3000000
# 1120        3300000
# 14018       3500000
#             ...
# 12196    1400000000
# 6661     1498000000
# 10740    1500000000
# 11783    1900000000
# 5628     1935000000
# Name: price, Length: 35443, dtype: int64

# %%
df_infl = pd.read_excel('./data/constructed/inflation-rate-in-kazakhstan-2028.xlsx', sheet_name='Data')

# %%
df_infl['Year'] = pd.to_numeric(df_infl['Year'].str.replace('*',''))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3196\408491033.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_infl['Year'] = pd.to_numeric(df_infl['Year'].str.replace('*',''))

# %%
df_infl=df_infl[pd.to_numeric(df_infl.Year)>=2016]

# %%
def get_perc_from_base(row):
    if row['Year'] == 2016:
        return 1.0
    else:
        return (1+row['Value']/100)

# %%
df_infl['Multiplier'] = df_infl.apply(lambda x: get_perc_from_base(x),axis=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3196\656660658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_infl['Multiplier'] = df_infl.apply(lambda x: get_perc_from_base(x),axis=1)

# %%
for elem in range(18, 18 + df_infl.__len__()):
    if elem != 18:
        df_infl.at[elem,'Multiplier'] = df_infl.at[elem,'Multiplier']*df_infl.at[elem-1,'Multiplier']

# %%
df_infl
# Out:
#     Year  Value  Unit  Multiplier
# 18  2016  14.56  in %    1.000000
# 19  2017   7.43  in %    1.074300
# 20  2018   6.03  in %    1.139080
# 21  2019   5.24  in %    1.198768
# 22  2020   6.80  in %    1.280284
# 23  2021   8.00  in %    1.382707
# 24  2022  14.96  in %    1.589560
# 25  2023  14.83  in %    1.825292
# 26  2024   8.55  in %    1.981354
# 27  2025   6.19  in %    2.104000
# 28  2026   5.56  in %    2.220982
# 29  2027   5.24  in %    2.337362
# 30  2028   4.70  in %    2.447218

# %%
df_join = df_join.merge(df_infl[['Year','Multiplier']], left_on='YEAR',right_on='Year').drop(columns=['Year'])

# %%
df_join['price_adj'] = df_join['price']/df_join['Multiplier']

# %%
sns.scatterplot(df_join, x='krisha_id', y='price_adj',hue='YEAR', palette='bright')

# plt.xlim(left = 0,right=0.6e8)
# plt.ylim(top=0.25e9)
# Out:
# <AxesSubplot: xlabel='krisha_id', ylabel='price_adj'>

# %%
sns.scatterplot(df_join, x='krisha_id', y='price_adj',hue='YEAR', palette='bright')
# Out:
# <AxesSubplot: xlabel='krisha_id', ylabel='price_adj'>
