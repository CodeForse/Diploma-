# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_excel('./data/data2023.xlsx')

# %%
df_m = pd.read_excel('./data/data2023m.xlsx')

# %%
df.seller.unique()
# Out:
# array(['Company', 'Krisha specialist', 'New builded house', 'Specialist',
#        'Owner of the house'], dtype=object)

# %%
df = df[df.seller=='New builded house']

# %%
df_m = df_m[df_m.seller=='Новостройка']

# %%
df_join = df[['krisha_id','price']].merge(df_m[['krisha_id','price']].rename(columns={'price':'price_may'}),on='krisha_id')

# %%
sns.histplot(df_join.price_may - df_join.price)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
df_join['price_dif'] = df_join.price_may - df_join.price

# %%
sns.scatterplot(df_join, x='krisha_id', y='price_dif')
plt.xlim(left=6.4e8)
# Out:
# (640000000.0, 714240241.5)

# %%
(df_join['price_dif']== 0).value_counts()
# Out:
# True     127
# False    117
# Name: price_dif, dtype: int64

# %% [markdown]
# Цены сохранили свой паттерн от чего то там
# но могла двигаться в ту или иную сторону
# Предположительно пару месяцев не достаточно для решения cold entry
